# %% [markdown]
# # AGENTS_026 Demo Notebook
#
# Run the offline incident workflow without launching Streamlit.

# %%
from agents import orchestrate_incident
from config import DEFAULT_INCIDENT
from models import IncidentInput

result = orchestrate_incident(IncidentInput(**DEFAULT_INCIDENT), approval_status="approved", approved_by="notebook")
result.to_dict()
